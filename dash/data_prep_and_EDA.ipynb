# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
matplotlib.rcParams['figure.figsize'] = (12, 8)

# %% [markdown]
# # Data Preparation

# %%
df = pd.read_excel('tfl-daily-cycle-hires.xls', sheet_name='Data', usecols=['Day', 'Number of Bicycle Hires'], index_col=0)
print(df.shape)
df.head()
# Out:
# (3077, 1)
#             Number of Bicycle Hires
# Day
# 2010-07-30                     6897
# 2010-07-31                     5564
# 2010-08-01                     4303
# 2010-08-02                     6642
# 2010-08-03                     7966

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3077 entries, 2010-07-30 to 2018-12-31
# Data columns (total 1 columns):
# Number of Bicycle Hires    3077 non-null int64
# dtypes: int64(1)
# memory usage: 48.1 KB

# %%
df.to_csv('cycle-hires-prepared.csv')

# %% [markdown]
# # Exploratory Data Analysis
#
# Graphs to recreate in dashboard.

# %%
df.plot();

# %%
df.hist(bins=20);

# %%
df.groupby(df.index.month).mean().plot(kind='bar');

# %%
ax = df.groupby(df.index.weekday).mean().plot(kind='bar')
ax.set_xticklabels(['Sun', 'Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat']);
